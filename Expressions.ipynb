# %% [markdown]
# <a href="https://colab.research.google.com/github/avikedare230455-cmd/ML/blob/main/Expressions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=9;
print(n,"Binary",format(n,'b'));
print(n,'*2',n<<1,format(n<<1,'b'));
print(n,'/2',n>>1,format(n>>1,'b'));
# Out:
# 9 Binary 1001
# 9 *2 18 10010
# 9 /2 4 100

# %%
x = True;
y = False;

print('x and y ', x and y);
print('x and y ', x or y);
print('x and y ', not x);

print('x and y ', x & y);
print('x and y ', x | y);
print('x and y ', x);
# Out:
# x and y  False
# x and y  True
# x and y  False
# x and y  False
# x and y  True
# x and y  True

# %%
x = 4;
y = 2;
print("x & y",x&y);
print("x & y",x|y);
print("x & y",x^y);
# Out:
# x & y 0
# x & y 6
# x & y 6

# %%
x = "HELLO world";
print('H' in x);
print('h' not in x);
# Out:
# True
# True

# %%
#import cmath

a=complex(20+5j);
b = complex(5+3j);
print("a+b",a+b);
print("a-b",a-b);
# Out:
# a+b (25+8j)
# a-b (15+2j)

# %%
a=input("get value of a");
b=input("get valuse of b");
c=input("get value of c");
import math;
s=(int(a) +int(b)+int(c))/2;
print(s);
area = s*(s-int(a))*(s-int(b))*(s-int(c));
print(math.sqrt(area));
# Out:
# get value of a2
# get valuse of b4
# get value of c6
# 6.0
# 0.0

# %%
age =18;
if(age>=18):
  if(age==18):
    print("Just eligible");
  else:
    print("eligible");
else :
  print("Not eligible");

c = input("Enter a char ");

if(c in "AaEeiIuUOo"):
  print("Vowel");
else :
  print("Conso");
# Out:
# Just eligible
# Enter a chare
# Vowel

# %%
c = input("Enter a char ");

if(c in "1234567890"):
  print("Number");
elif 48 <= ord(c) <= 57:
  print("Lower");
else :
  print("upper")
# Out:
# Enter a char 1
# Number

# %%
n = int(input("enter a number"));
result = [n*i for i in range(1,11) ];
print(result);
# Out:
# enter a number5
# [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

# %%
n = int(input("enter a no.: "))
fact = 1
for i in range(1, n + 1):
    fact *= i

print(fact)
# Out:
# enter a no.: 5
# 120

# %%
maxi = 0;
while(True):

    n = int(input("enter (0 to stop)"));
    if(n==0):
      break;
    maxi = max(maxi,n);
print(maxi);
# Out:
# enter (0 to stop)12
# enter (0 to stop)23
# enter (0 to stop)342
# enter (0 to stop)0
# 342

# %%
class Car:
  def __init__(self,brand,model,year):
    self.brand=brand;
    self.model=model;
    self.year=year;

  def display(self):
    print(f"Car : {self.brand} {self.model},{self.year}");

car1 = Car("Totoya","X12",1234);
car2 = Car("BMW","X23","2026");

car1.display();
# Out:
# Car : Totoya X12,1234

# %%
class Employee:
  def __init__(self,Name,age,salary):
    self.Name=Name;
    self.age=age;
    self.salary=salary;

  def display(self):
      print(f"Employee {self.Name} {self.age} {self.salary}")

  def up(self):
    self.salary=self.salary+100;


empl1 = Employee("Ram","23",12000);
empl1.display();
empl1.up();
empl1.display();
# Out:
# Employee Ram 23 12000
# Employee Ram 23 12100

# %%
class Employee:
  def __init__(self,Name,age,salary):
    self.Name=Name;
    self.age=age;
    self.salary=salary;

  def display(self):
      print(f"Employee {self.Name} {self.age} {self.salary}")

  def up(self):
    self.salary=self.salary+100;
Employees = [
    Employee("Rohit",23,12222),
    Employee("Mohit",34,120000)
]

for E in Employees:
  E.display();
# Out:
# Employee Rohit 23 12222
# Employee Mohit 34 120000

# %%
class Employee:
  def __init__(self,Name,age,salary):
    self.Name=Name;
    self.age=age;
    self.salary=salary;

  def display(self):
      print(f"Employee {self.Name} {self.age} {self.salary}")

  def up(self):
    self.salary=self.salary+100;
employees = {
    101: Employee("Rohit",23,12222),
    102: Employee("Mohit",34,120000)
}

for eid ,emp in employees.items():
  print(f"Name : {emp.Name}, Age : {emp.age}");
# Out:
# Name : Rohit, Age : 23
# Name : Mohit, Age : 34
